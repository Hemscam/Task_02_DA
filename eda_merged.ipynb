# %% [markdown]
# # EDA Notebook — Merged Dataset
# This notebook was generated automatically. It loads the annex files, merges them on keys (Item Code / Category Code), and performs exploratory analysis. Files created:
#
# - /mnt/data/merged_data.csv
# - /mnt/data/EDA_Merged_Report.pdf

# %%
import pandas as pd
merged = pd.read_csv('/mnt/data/merged_data.csv')
merged.info()
merged.head()

# %%
merged.describe(include='all')
